# %%
import os 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt


dir_data='./data/'

f_train=os.path.join(dir_data,'application_train.csv')
train=pd.read_csv(f_train)
train.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
train.corr()['TARGET'].sort_values()
# Out:
# EXT_SOURCE_3                  -0.178919
# EXT_SOURCE_2                  -0.160472
# EXT_SOURCE_1                  -0.155317
# DAYS_EMPLOYED                 -0.044932
# FLOORSMAX_AVG                 -0.044003
# FLOORSMAX_MEDI                -0.043768
# FLOORSMAX_MODE                -0.043226
# AMT_GOODS_PRICE               -0.039645
# REGION_POPULATION_RELATIVE    -0.037227
# ELEVATORS_AVG                 -0.034199
# ELEVATORS_MEDI                -0.033863
# FLOORSMIN_AVG                 -0.033614
# FLOORSMIN_MEDI                -0.033394
# LIVINGAREA_AVG                -0.032997
# LIVINGAREA_MEDI               -0.032739
# FLOORSMIN_MODE                -0.032698
# TOTALAREA_MODE                -0.032596
# ELEVATORS_MODE                -0.032131
# LIVINGAREA_MODE               -0.030685
# AMT_CREDIT                    -0.030369
# APARTMENTS_AVG                -0.029498
# APARTMENTS_MEDI               -0.029184
# FLAG_DOCUMENT_6               -0.028602
# ...

# %%
plt.plot( train.EXT_SOURCE_3,train.TARGET , '.')
plt.xlabel('EXT_SOURCE_3')
plt.ylabel('TARGET')
plt.show()

# %%
mdata=train.groupby(['EXT_SOURCE_3'])['TARGET']
a=np.array(mdata)
plt.boxplot(a,labels='gg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-b6f47aee140a> in <module>()
#       1 mdata=train.groupby(['EXT_SOURCE_3'])['TARGET']
# ----> 2 a=np.array(mdata)
#       3 plt.boxplot(a,labels='gg')
#
# ValueError: setting an array element with a sequence.
